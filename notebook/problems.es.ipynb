# %% [markdown]
# # Ejercicios de probabilidad

# %% [markdown]
# ## Ejercicio 1
#
# Dos dados se lanzan una vez y se observa el total obtenido. Usa una simulación para encontrar la probabilidad estimada de que la puntuación sea mayor a 7 o un número par. Una simulación es una repetición del mismo experimento multiples veces para observar su comportamiento:
#
# - Ejecuta el experimento 1000 veces (lanza 2 dados 1000 veces, y suma el número de ambos dados).
# - Lleva ua cuenta de los números y las veces que la suma fue mayor a 7 o un número par.
# - Divide el número del paso 2 entre el número de iteraciones(1000).

# %%
import numpy as np
import pandas as pd

def lanzar_dados(i):
    experimento = np.random.randint(1,7,size = (i,2))
    suma = experimento.sum(axis=1)
    condiciones = (suma > 7) | (suma % 2 == 0)
    probabilidad = np.mean(condiciones)
    return probabilidad

print (f'la probabilidad estimada es de {lanzar_dados(1000)}')
# Out:
# la probabilidad estimada es de 0.663

# %% [markdown]
# ## Ejercicio 2
#
# Una caja contiene 10 bolas blancas, 20 bolas rojas y 30 bolas verdes. Si tomamos 5 bolas de la caja reemplazándolas (tomando una bola, anotando el color y luego regresandola a la caja). Queremos saber la probabilidad de:
#
# 1. Tomar 3 blancas y 2 rojas.
# 2. Toas todas del mismo color.
#
# Ejecuta el experimento 1000 veces y calcula las probabilidades que mencionadas.

# %%
import numpy as np

ball_box = {}

# Crea la cajas con las bolas
for i in range(60):
    if i < 11:
        ball_box[i] = "White"
    elif (i > 10) and (i < 31):
        ball_box[i] = "Red"
    else:
        ball_box[i] = "Green"

def balls(n_exp):
    np.random.seed(13)
    condicion1 = 0
    condicion2 = 0
    
    for i in range(n_exp):
        color = []
    
        for i in range(5):
            color.append(ball_box[np.random.randint(1, 60)])
        color = np.array(color)
        white = sum(color == "White")
        red = sum(color == "Red")
        green = sum(color == "Green")
        if white == 3 and red == 2:
            condicion1 += 1
        elif white == 5 or red == 5 or green == 5:
            condicion2 +=1
        
        
    return condicion1/n_exp, condicion2/n_exp
      
print(balls(1000))

print(f'la probabilidad de que sa quemos 3 bolas blancas y 2 rojas es de {balls(1000)[0]}')

print(f'la probabilidad  de que saquemos todas del mismo color es de {balls(1000)[1]}')
# Out:
# (0.003, 0.034)
# la probabilidad de que sa quemos 3 bolas blancas y 2 rojas es de 0.003
# la probabilidad  de que saquemos todas del mismo color es de 0.034
